# %%
import numpy as np
import cv2

# %%
block_width_px = 705
block_width_mm = 30.0
scale = block_width_mm / block_width_px

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img1 = cv.imread('block-faces/Book.png')
img1 = cv2.GaussianBlur(img1,(15,15),cv2.BORDER_DEFAULT).copy()
img2 = cv.imread('img1.jpg')

if img1 is None or img2 is None:
    print("Image Not Found")

# Initiate SIFT detector
orb = cv.SIFT_create()
# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.9*n.distance:
        good.append([m])
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x2b066899f10>, None)

# %%
# Out:
# array([[183, 183, 183, ..., 191, 189, 192],
#        [189, 187, 185, ..., 190, 189, 192],
#        [191, 188, 184, ..., 190, 188, 191],
#        ...,
#        [173, 175, 173, ..., 200, 205, 209],
#        [175, 174, 172, ..., 197, 203, 205],
#        [178, 174, 173, ..., 201, 204, 202]], dtype=uint8)

# %%
type(img1)
# Out:
# numpy.ndarray
